# %%
import seaborn as sns
from numpy import nan
import numpy as np

# %%
data = clean_data("""1.                 nan         nan         nan         nan         nan
         nan         nan         nan         nan  1.                 nan
  0.01449672 -0.03579766 -0.02769649 -0.02225721  0.05063043 -0.06886961
         nan         nan  1.                 nan         nan         nan
         nan         nan         nan         nan  0.01449672         nan
  1.          0.0264953   0.01330074 -0.00100337  0.00631166 -0.00232502
         nan -0.03579766         nan  0.0264953   1.          0.1529715
  0.03626369  0.0700184  -0.13741113         nan -0.02769649         nan
  0.01330074  0.1529715   1.          0.00575396  0.00428415  0.004227
         nan -0.02225721         nan -0.00100337  0.03626369  0.00575396
  1.         -0.0718092  -0.07953199         nan  0.05063043         nan
  0.00631166  0.0700184   0.00428415 -0.0718092   1.         -0.03360301
         nan -0.06886961         nan -0.00232502 -0.13741113  0.004227
 -0.07953199 -0.03360301  1.""")

# %%
data = np.reshape(data, (9, 9))

my_labels = ["danceability", "duration", "energy", "key", "loudness", "tempo", "year", "artist_id", "genre_id"]

sns.heatmap(data, xticklabels=my_labels, yticklabels=my_labels)
# Out:
# <Axes: >
